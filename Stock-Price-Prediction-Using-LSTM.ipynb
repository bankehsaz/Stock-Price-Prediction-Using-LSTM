# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from keras.models import Sequential
from keras.layers import Input, Dense, LSTM, Dropout
from sklearn.metrics import mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import StandardScaler
import yfinance as yf

# %%
# Get data from Yahoo finance
df = yf.download('GLD', start='2020-01-01')
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  143.860001  144.210007  143.399994  143.949997  143.949997
# 2020-01-03  145.750000  146.320007  145.399994  145.860001  145.860001
# 2020-01-06  148.440002  148.479996  146.949997  147.389999  147.389999
# 2020-01-07  147.570007  148.139999  147.429993  147.970001  147.970001
# 2020-01-08  148.490005  148.610001  146.139999  146.860001  146.860001
#
#               Volume
# Date
# 2020-01-02   7733800
# 2020-01-03  12272800
# 2020-01-06  14403300
# 2020-01-07   7978500
# 2020-01-08  22248500

# %%
# Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 930 entries, 2020-01-02 to 2023-09-12
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       930 non-null    float64
#  1   High       930 non-null    float64
#  2   Low        930 non-null    float64
#  3   Close      930 non-null    float64
#  4   Adj Close  930 non-null    float64
#  5   Volume     930 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 50.9 KB

# %%
# Log Close
df['Log_Close'] = np.log(df['Close'])

# %%
# Compute the first difference of Log_Close(Log Returns)
df['Diff_Log_Close'] = df['Log_Close'].diff()

# %%
# Split data into train and test
Ntest = 10
train = df.iloc[:-Ntest]
test = df.iloc[-Ntest:]

# %%
# Standardize the Time Series values
scaler = StandardScaler()
train_scaled = scaler.fit_transform(train[['Diff_Log_Close']])
test_scaled = scaler.fit_transform(test[['Diff_Log_Close']])

# %%
# Boolean series to index df rows
train_idx = df.index <= train.index[-1]
test_idx = df.index > train.index[-1]

# %%
# Put the Scaled Log Return back to dataframe use the column name 'Scaled_Log_Ret'
# We use flatten function because Scikit-Learn returns 2D arrays
df.loc[train_idx, 'Scaled_Log_Ret'] = train_scaled.flatten()
df.loc[test_idx, 'Scaled_Log_Ret'] = test_scaled.flatten()

# %%
# Make Supervised Dataset
series = df['Scaled_Log_Ret'].dropna().to_numpy()
T = 10
X = []
Y = []

for t in range(len(series) - T):
  x = series[t: t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T, 1)
Y = np.array(Y)

print('X Shape: ', X.shape, 'Y Shape: ', Y.shape)
# Out:
# X Shape:  (919, 10, 1) Y Shape:  (919,)

# %%
# Split our supervised dataset into train and test
Xtrain, Xtest = X[:-Ntest], X[-Ntest:]
Ytrain, Ytest = Y[:-Ntest], Y[-Ntest:]

# %%
# Create our LSTM Model
model = Sequential()
model.add(Input(shape=(T,1)))
model.add(LSTM(units=20, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=20, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=20, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 20)            1760
#
#  dropout (Dropout)           (None, 10, 20)            0
#
#  lstm_1 (LSTM)               (None, 10, 20)            3280
#
#  dropout_1 (Dropout)         (None, 10, 20)            0
#
#  lstm_2 (LSTM)               (None, 20)                3280
#
#  dropout_2 (Dropout)         (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 8341 (32.58 KB)
# Trainable params: 8341 (32.58 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Call Compile Function
model.compile(loss='mse', optimizer='adam', metrics='mae')

# %%
# Call Fit Function
r = model.fit(Xtrain, Ytrain, epochs=100, validation_data=(Xtest, Ytest))
# Out:
# Epoch 1/100
# 29/29 [==============================] - 16s 94ms/step - loss: 1.0079 - mae: 0.7325 - val_loss: 0.9806 - val_mae: 0.7700
# Epoch 2/100
# 29/29 [==============================] - 0s 14ms/step - loss: 1.0062 - mae: 0.7324 - val_loss: 0.9853 - val_mae: 0.7723
# Epoch 3/100
# 29/29 [==============================] - 0s 14ms/step - loss: 1.0053 - mae: 0.7316 - val_loss: 0.9930 - val_mae: 0.7696
# Epoch 4/100
# 29/29 [==============================] - 0s 16ms/step - loss: 1.0046 - mae: 0.7306 - val_loss: 0.9964 - val_mae: 0.7714
# Epoch 5/100
# 29/29 [==============================] - 1s 18ms/step - loss: 1.0037 - mae: 0.7316 - val_loss: 0.9911 - val_mae: 0.7739
# Epoch 6/100
# 29/29 [==============================] - 0s 17ms/step - loss: 1.0029 - mae: 0.7323 - val_loss: 0.9939 - val_mae: 0.7705
# Epoch 7/100
# 29/29 [==============================] - 0s 16ms/step - loss: 1.0009 - mae: 0.7314 - val_loss: 0.9966 - val_mae: 0.7714
# Epoch 8/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.9999 - mae: 0.7316 - val_loss: 1.0087 - val_mae: 0.7732
# Epoch 9/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.9957 - mae: 0.7295 - val_loss: 1.0241 - val_mae: 0.7748
# Epoch 10/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.9956 - mae: 0.7300 - val_loss: 1.0178 - val_mae: 0.7788
# Epoch 11/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.9892 - mae: 0.7333 - val_loss: 1.0495 - val_mae: 0.7816
# Epoch 12/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.9954 - mae: 0.7298 - val_loss: 1.0404 - val_mae: 0.7822
# Epoch 13/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.9933 - mae: 0.7303 - val_loss: 1.0497 - val_mae: 0.7804
# Epoch 14/100
# 29/29 [==============================] - 1s 24ms/step - loss: 0.9956 - mae: 0.7298 - val_loss: 1.0267 - val_mae: 0.7767
# Epoch 15/100
# 29/29 [==============================] - 1s 41ms/step - loss: 0.9857 - mae: 0.7282 - val_loss: 1.0345 - val_mae: 0.7763
# Epoch 16/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.9915 - mae: 0.7304 - val_loss: 1.0479 - val_mae: 0.7797
# Epoch 17/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.9884 - mae: 0.7335 - val_loss: 1.0382 - val_mae: 0.7778
# Epoch 18/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.9893 - mae: 0.7280 - val_loss: 1.0357 - val_mae: 0.7757
# Epoch 19/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.9924 - mae: 0.7324 - val_loss: 1.0290 - val_mae: 0.7795
# Epoch 20/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9799 - mae: 0.7278 - val_loss: 1.0395 - val_mae: 0.7763
# Epoch 21/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9813 - mae: 0.7286 - val_loss: 1.0401 - val_mae: 0.7761
# Epoch 22/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9850 - mae: 0.7283 - val_loss: 1.0314 - val_mae: 0.7762
# Epoch 23/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9740 - mae: 0.7269 - val_loss: 1.0422 - val_mae: 0.7784
# Epoch 24/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9846 - mae: 0.7273 - val_loss: 1.0489 - val_mae: 0.7768
# Epoch 25/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9713 - mae: 0.7252 - val_loss: 1.0370 - val_mae: 0.7745
# Epoch 26/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9770 - mae: 0.7263 - val_loss: 1.0386 - val_mae: 0.7797
# Epoch 27/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9870 - mae: 0.7294 - val_loss: 1.0349 - val_mae: 0.7786
# Epoch 28/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9752 - mae: 0.7275 - val_loss: 1.0350 - val_mae: 0.7828
# Epoch 29/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9740 - mae: 0.7269 - val_loss: 1.0398 - val_mae: 0.7774
# Epoch 30/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9891 - mae: 0.7283 - val_loss: 1.0424 - val_mae: 0.7731
# Epoch 31/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.9703 - mae: 0.7267 - val_loss: 1.0357 - val_mae: 0.7795
# Epoch 32/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9755 - mae: 0.7272 - val_loss: 1.0364 - val_mae: 0.7755
# Epoch 33/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.9767 - mae: 0.7268 - val_loss: 1.0335 - val_mae: 0.7704
# Epoch 34/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.9693 - mae: 0.7248 - val_loss: 1.0260 - val_mae: 0.7786
# Epoch 35/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9770 - mae: 0.7276 - val_loss: 1.0395 - val_mae: 0.7743
# Epoch 36/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9613 - mae: 0.7233 - val_loss: 1.0321 - val_mae: 0.7708
# Epoch 37/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9763 - mae: 0.7251 - val_loss: 1.0355 - val_mae: 0.7777
# Epoch 38/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9735 - mae: 0.7286 - val_loss: 1.0302 - val_mae: 0.7728
# Epoch 39/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9647 - mae: 0.7265 - val_loss: 1.0269 - val_mae: 0.7736
# Epoch 40/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9669 - mae: 0.7239 - val_loss: 1.0326 - val_mae: 0.7709
# Epoch 41/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9688 - mae: 0.7272 - val_loss: 1.0251 - val_mae: 0.7785
# Epoch 42/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9714 - mae: 0.7255 - val_loss: 1.0225 - val_mae: 0.7720
# Epoch 43/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9627 - mae: 0.7283 - val_loss: 1.0227 - val_mae: 0.7743
# Epoch 44/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9601 - mae: 0.7238 - val_loss: 1.0240 - val_mae: 0.7731
# Epoch 45/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9666 - mae: 0.7227 - val_loss: 1.0223 - val_mae: 0.7748
# Epoch 46/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9613 - mae: 0.7247 - val_loss: 1.0242 - val_mae: 0.7712
# Epoch 47/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9686 - mae: 0.7259 - val_loss: 1.0200 - val_mae: 0.7763
# Epoch 48/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9662 - mae: 0.7254 - val_loss: 1.0209 - val_mae: 0.7708
# Epoch 49/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9663 - mae: 0.7269 - val_loss: 1.0205 - val_mae: 0.7760
# Epoch 50/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9548 - mae: 0.7216 - val_loss: 1.0223 - val_mae: 0.7740
# Epoch 51/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9733 - mae: 0.7260 - val_loss: 1.0250 - val_mae: 0.7715
# Epoch 52/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.9553 - mae: 0.7232 - val_loss: 1.0191 - val_mae: 0.7720
# Epoch 53/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9761 - mae: 0.7279 - val_loss: 1.0226 - val_mae: 0.7745
# Epoch 54/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.9612 - mae: 0.7237 - val_loss: 1.0191 - val_mae: 0.7745
# Epoch 55/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9586 - mae: 0.7238 - val_loss: 1.0242 - val_mae: 0.7698
# Epoch 56/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9580 - mae: 0.7217 - val_loss: 1.0219 - val_mae: 0.7742
# Epoch 57/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.9535 - mae: 0.7232 - val_loss: 1.0148 - val_mae: 0.7770
# Epoch 58/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9532 - mae: 0.7213 - val_loss: 1.0160 - val_mae: 0.7692
# Epoch 59/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9573 - mae: 0.7230 - val_loss: 1.0128 - val_mae: 0.7672
# Epoch 60/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9537 - mae: 0.7230 - val_loss: 1.0137 - val_mae: 0.7721
# Epoch 61/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9686 - mae: 0.7249 - val_loss: 1.0136 - val_mae: 0.7714
# Epoch 62/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9498 - mae: 0.7220 - val_loss: 1.0116 - val_mae: 0.7748
# Epoch 63/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9632 - mae: 0.7261 - val_loss: 1.0131 - val_mae: 0.7702
# Epoch 64/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9518 - mae: 0.7231 - val_loss: 1.0170 - val_mae: 0.7691
# Epoch 65/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9491 - mae: 0.7208 - val_loss: 1.0148 - val_mae: 0.7711
# Epoch 66/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9643 - mae: 0.7252 - val_loss: 1.0217 - val_mae: 0.7688
# Epoch 67/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9616 - mae: 0.7266 - val_loss: 1.0165 - val_mae: 0.7698
# Epoch 68/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9628 - mae: 0.7242 - val_loss: 1.0170 - val_mae: 0.7712
# Epoch 69/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9643 - mae: 0.7263 - val_loss: 1.0207 - val_mae: 0.7733
# Epoch 70/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9551 - mae: 0.7233 - val_loss: 1.0176 - val_mae: 0.7734
# Epoch 71/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9516 - mae: 0.7230 - val_loss: 1.0095 - val_mae: 0.7688
# Epoch 72/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9551 - mae: 0.7209 - val_loss: 1.0153 - val_mae: 0.7707
# Epoch 73/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9475 - mae: 0.7208 - val_loss: 1.0135 - val_mae: 0.7707
# Epoch 74/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9483 - mae: 0.7232 - val_loss: 1.0245 - val_mae: 0.7677
# Epoch 75/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9441 - mae: 0.7219 - val_loss: 1.0116 - val_mae: 0.7680
# Epoch 76/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9406 - mae: 0.7174 - val_loss: 1.0120 - val_mae: 0.7689
# Epoch 77/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9465 - mae: 0.7209 - val_loss: 1.0136 - val_mae: 0.7709
# Epoch 78/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9404 - mae: 0.7195 - val_loss: 1.0196 - val_mae: 0.7645
# Epoch 79/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9332 - mae: 0.7129 - val_loss: 1.0140 - val_mae: 0.7711
# Epoch 80/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9436 - mae: 0.7204 - val_loss: 1.0162 - val_mae: 0.7710
# Epoch 81/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9489 - mae: 0.7226 - val_loss: 1.0151 - val_mae: 0.7704
# Epoch 82/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9466 - mae: 0.7179 - val_loss: 1.0130 - val_mae: 0.7732
# Epoch 83/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9469 - mae: 0.7226 - val_loss: 1.0170 - val_mae: 0.7708
# Epoch 84/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9416 - mae: 0.7198 - val_loss: 1.0218 - val_mae: 0.7711
# Epoch 85/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9456 - mae: 0.7205 - val_loss: 1.0104 - val_mae: 0.7707
# Epoch 86/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9639 - mae: 0.7286 - val_loss: 1.0031 - val_mae: 0.7653
# Epoch 87/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9496 - mae: 0.7205 - val_loss: 1.0097 - val_mae: 0.7698
# Epoch 88/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9443 - mae: 0.7180 - val_loss: 1.0143 - val_mae: 0.7677
# Epoch 89/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9431 - mae: 0.7183 - val_loss: 1.0222 - val_mae: 0.7691
# Epoch 90/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9369 - mae: 0.7176 - val_loss: 1.0232 - val_mae: 0.7664
# Epoch 91/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9341 - mae: 0.7188 - val_loss: 1.0193 - val_mae: 0.7736
# Epoch 92/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9333 - mae: 0.7162 - val_loss: 1.0231 - val_mae: 0.7641
# Epoch 93/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9466 - mae: 0.7233 - val_loss: 1.0150 - val_mae: 0.7653
# Epoch 94/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9382 - mae: 0.7166 - val_loss: 1.0142 - val_mae: 0.7709
# Epoch 95/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9380 - mae: 0.7196 - val_loss: 1.0178 - val_mae: 0.7659
# Epoch 96/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9366 - mae: 0.7186 - val_loss: 1.0107 - val_mae: 0.7718
# Epoch 97/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9329 - mae: 0.7164 - val_loss: 1.0147 - val_mae: 0.7652
# Epoch 98/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.9417 - mae: 0.7180 - val_loss: 1.0167 - val_mae: 0.7697
# Epoch 99/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9359 - mae: 0.7196 - val_loss: 1.0116 - val_mae: 0.7661
# Epoch 100/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.9275 - mae: 0.7147 - val_loss: 1.0085 - val_mae: 0.7689

# %%
# History's Keys
r.history.keys()
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
# Plot
plt.plot(r.history['loss'], label='Train Loss')
plt.plot(r.history['val_loss'], label='Test Loss')
plt.legend();

# %%
# First T values are not predictable
train_idx[:T+1] = False

# %%
# Make Prediction
Ptrain = model.predict(Xtrain)
Ptest = model.predict(Xtest)
Ptrain.shape
# Out:
# 29/29 [==============================] - 1s 3ms/step
# 1/1 [==============================] - 0s 22ms/step
# (909, 1)

# %%
# Invert the Scaling
Ptrain = scaler.inverse_transform(Ptrain).flatten()
Ptest = scaler.inverse_transform(Ptest).flatten()

# %%
# Store Diff Predictions
df.loc[train_idx, 'Diff_LSTM_Train_Pred'] = Ptrain
df.loc[test_idx, 'Diff_LSTM_Test_Pred'] = Ptest

# %%
# Plot
px.line(df, x=df.index, y=['Diff_Log_Close', 'Diff_LSTM_Train_Pred', 'Diff_LSTM_Test_Pred'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2fea7c39-bf42-41e4-a566-7fe608ef80fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fea7c39-bf42-41e4-a566-7fe608ef80fd")) {                    Plotly.newPlot(                        "2fea7c39-bf42-41e4-a566-7fe608ef80fd",                        [{"hovertemplate":"variable=Diff_Log_Close\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Diff_Log_Close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Diff_Log_Close","showlegend":true,"x":["2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00: ...

# %%
# Shifted Log Close values will use to Compute Un-Differenced Predictions
df['Shifted_Log_Close'] = df['Log_Close'].shift(1)
prev = df['Shifted_Log_Close']

# %%
# 1 step forecast
df.loc[train_idx, '1_Step_pred_Train'] = prev[train_idx] + Ptrain
df.loc[test_idx, '1_Step_pred_Test'] = prev[test_idx] + Ptest

# %%
# Plot 1-Step Forecast
px.line(df, x=df.index, y=['Log_Close', '1_Step_pred_Train', '1_Step_pred_Test'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d5796d2f-cfbc-4422-a844-a2a9892a97d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5796d2f-cfbc-4422-a844-a2a9892a97d6")) {                    Plotly.newPlot(                        "d5796d2f-cfbc-4422-a844-a2a9892a97d6",                        [{"hovertemplate":"variable=Log_Close\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Log_Close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Log_Close","showlegend":true,"x":["2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28 ...

# %%
# Multi-Step Forecast
multistep_predictions = []

# %%
# First test input
last_x = Xtrain[-1]

# %%
# LSTM input must be 3-dimensional
while len(multistep_predictions) < Ntest:
  p = model.predict(last_x.reshape(-1, T,1))[0] # [0] Returns just a number otherwise we'll have a bunch of array.
  # Update the predictions list
  multistep_predictions.append(p)
  # Make the new input
  last_x = np.roll(last_x, -1) # Roll function spins our list 1 unit.
  last_x[-1] = p # P value will replace with last value of our list.

multistep_predictions
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# [array([0.00939688], dtype=float32),
#  array([0.00834996], dtype=float32),
#  array([0.00919327], dtype=float32),
#  array([0.01256812], dtype=float32),
#  array([0.0154057], dtype=float32),
#  array([0.01620534], dtype=float32),
#  array([0.0121331], dtype=float32),
#  array([0.00547158], dtype=float32),
#  array([0.00768505], dtype=float32),
#  array([0.00825288], dtype=float32)]

# %%
# Invert the Scaling
multistep_predictions = np.array(multistep_predictions)
multistep_predictions = scaler.inverse_transform(multistep_predictions.reshape(-1,1)).flatten() # reshape because required for scikit-learn

# %%
# Last-Known train value
last_train = train.iloc[-1]['Log_Close']

# %%
# Save multi-step forecast to dataframe
df.loc[test_idx, 'Multi_Step'] = last_train + np.cumsum(multistep_predictions)

# %%
# Plot 1-Step and Molti-Step Forecast
px.line(df, x=df.index, y=['Log_Close', '1_Step_pred_Test', 'Multi_Step'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="41b959c9-022d-4952-a56b-59cfa32d46e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41b959c9-022d-4952-a56b-59cfa32d46e3")) {                    Plotly.newPlot(                        "41b959c9-022d-4952-a56b-59cfa32d46e3",                        [{"hovertemplate":"variable=Log_Close\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Log_Close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Log_Close","showlegend":true,"x":["2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28 ...

# %%
# Make Multi-Output Supervised Dataset
Tx = T # Tx represent the number of time steps in the input
Ty = Ntest # Ty represent the number of time steps in the output
X = []
Y = []
for t in range(len(series) - Tx - Ty + 1):
  x = series[t: t+Tx]
  X.append(x)
  y = series[t+Tx: t+Tx+Ty]
  Y.append(y)

X = np.array(X).reshape(-1, Tx, 1)
Y = np.array(Y).reshape(-1, Ty)

print('X shape: ', X.shape, 'Y shape: ', Y.shape)
# Out:
# X shape:  (910, 10, 1) Y shape:  (910, 10)

# %%
# Split data into train and test
Xtrain_m, Ytrain_m = X[:-1], Y[:-1]
Xtest_m, Ytest_m = X[-1:], Y[-1:]

# %%
# Create our LSTM Model
model = Sequential()
model.add(Input(shape=(Tx,1)))
model.add(LSTM(units=20, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=20, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=20, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=Ty))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 10, 20)            1760
#
#  dropout_3 (Dropout)         (None, 10, 20)            0
#
#  lstm_4 (LSTM)               (None, 10, 20)            3280
#
#  dropout_4 (Dropout)         (None, 10, 20)            0
#
#  lstm_5 (LSTM)               (None, 20)                3280
#
#  dropout_5 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 8530 (33.32 KB)
# Trainable params: 8530 (33.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Call Compile Function
model.compile(loss='mse', optimizer='adam', metrics='mae')

# %%
# Call Fit Function
r = model.fit(Xtrain, Ytrain, epochs=100, validation_data=(Xtest, Ytest))
# Out:
# Epoch 1/100
# 29/29 [==============================] - 7s 48ms/step - loss: 1.0068 - mae: 0.7302 - val_loss: 0.9981 - val_mae: 0.7683
# Epoch 2/100
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0053 - mae: 0.7300 - val_loss: 0.9953 - val_mae: 0.7708
# Epoch 3/100
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0053 - mae: 0.7304 - val_loss: 0.9944 - val_mae: 0.7691
# Epoch 4/100
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0051 - mae: 0.7303 - val_loss: 0.9935 - val_mae: 0.7706
# Epoch 5/100
# 29/29 [==============================] - 0s 10ms/step - loss: 1.0038 - mae: 0.7301 - val_loss: 0.9917 - val_mae: 0.7684
# Epoch 6/100
# 29/29 [==============================] - 0s 10ms/step - loss: 1.0046 - mae: 0.7309 - val_loss: 0.9882 - val_mae: 0.7701
# Epoch 7/100
# 29/29 [==============================] - 0s 11ms/step - loss: 1.0047 - mae: 0.7316 - val_loss: 0.9923 - val_mae: 0.7718
# Epoch 8/100
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0033 - mae: 0.7308 - val_loss: 0.9948 - val_mae: 0.7713
# Epoch 9/100
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0017 - mae: 0.7308 - val_loss: 0.9901 - val_mae: 0.7701
# Epoch 10/100
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0009 - mae: 0.7308 - val_loss: 0.9938 - val_mae: 0.7723
# Epoch 11/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9982 - mae: 0.7314 - val_loss: 1.0039 - val_mae: 0.7775
# Epoch 12/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9959 - mae: 0.7311 - val_loss: 1.0150 - val_mae: 0.7736
# Epoch 13/100
# 29/29 [==============================] - 0s 9ms/step - loss: 1.0015 - mae: 0.7316 - val_loss: 1.0024 - val_mae: 0.7771
# Epoch 14/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9947 - mae: 0.7323 - val_loss: 1.0074 - val_mae: 0.7746
# Epoch 15/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9954 - mae: 0.7299 - val_loss: 1.0092 - val_mae: 0.7770
# Epoch 16/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9917 - mae: 0.7321 - val_loss: 1.0135 - val_mae: 0.7784
# Epoch 17/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9883 - mae: 0.7299 - val_loss: 1.0157 - val_mae: 0.7744
# Epoch 18/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9894 - mae: 0.7292 - val_loss: 1.0277 - val_mae: 0.7739
# Epoch 19/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9849 - mae: 0.7285 - val_loss: 1.0250 - val_mae: 0.7788
# Epoch 20/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9800 - mae: 0.7281 - val_loss: 1.0266 - val_mae: 0.7772
# Epoch 21/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9843 - mae: 0.7284 - val_loss: 1.0318 - val_mae: 0.7763
# Epoch 22/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.9801 - mae: 0.7285 - val_loss: 1.0303 - val_mae: 0.7789
# Epoch 23/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.9868 - mae: 0.7301 - val_loss: 1.0343 - val_mae: 0.7781
# Epoch 24/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9758 - mae: 0.7262 - val_loss: 1.0297 - val_mae: 0.7753
# Epoch 25/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.9742 - mae: 0.7270 - val_loss: 1.0333 - val_mae: 0.7774
# Epoch 26/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9890 - mae: 0.7293 - val_loss: 1.0224 - val_mae: 0.7791
# Epoch 27/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9857 - mae: 0.7317 - val_loss: 1.0246 - val_mae: 0.7761
# Epoch 28/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.9737 - mae: 0.7247 - val_loss: 1.0279 - val_mae: 0.7733
# Epoch 29/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9794 - mae: 0.7273 - val_loss: 1.0233 - val_mae: 0.7758
# Epoch 30/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9738 - mae: 0.7268 - val_loss: 1.0233 - val_mae: 0.7758
# Epoch 31/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9836 - mae: 0.7288 - val_loss: 1.0269 - val_mae: 0.7758
# Epoch 32/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9789 - mae: 0.7286 - val_loss: 1.0280 - val_mae: 0.7742
# Epoch 33/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.9791 - mae: 0.7272 - val_loss: 1.0290 - val_mae: 0.7766
# Epoch 34/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9820 - mae: 0.7292 - val_loss: 1.0326 - val_mae: 0.7723
# Epoch 35/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9776 - mae: 0.7264 - val_loss: 1.0237 - val_mae: 0.7751
# Epoch 36/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9648 - mae: 0.7236 - val_loss: 1.0289 - val_mae: 0.7778
# Epoch 37/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9745 - mae: 0.7260 - val_loss: 1.0269 - val_mae: 0.7797
# Epoch 38/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9689 - mae: 0.7264 - val_loss: 1.0328 - val_mae: 0.7766
# Epoch 39/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9664 - mae: 0.7270 - val_loss: 1.0278 - val_mae: 0.7786
# Epoch 40/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9681 - mae: 0.7255 - val_loss: 1.0273 - val_mae: 0.7770
# Epoch 41/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9714 - mae: 0.7269 - val_loss: 1.0280 - val_mae: 0.7783
# Epoch 42/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9629 - mae: 0.7264 - val_loss: 1.0299 - val_mae: 0.7737
# Epoch 43/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9646 - mae: 0.7235 - val_loss: 1.0281 - val_mae: 0.7796
# Epoch 44/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9593 - mae: 0.7217 - val_loss: 1.0296 - val_mae: 0.7749
# Epoch 45/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9660 - mae: 0.7262 - val_loss: 1.0271 - val_mae: 0.7801
# Epoch 46/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.9703 - mae: 0.7256 - val_loss: 1.0297 - val_mae: 0.7702
# Epoch 47/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9675 - mae: 0.7261 - val_loss: 1.0221 - val_mae: 0.7798
# Epoch 48/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9630 - mae: 0.7253 - val_loss: 1.0196 - val_mae: 0.7741
# Epoch 49/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9678 - mae: 0.7248 - val_loss: 1.0220 - val_mae: 0.7780
# Epoch 50/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9648 - mae: 0.7260 - val_loss: 1.0243 - val_mae: 0.7685
# Epoch 51/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9647 - mae: 0.7241 - val_loss: 1.0192 - val_mae: 0.7735
# Epoch 52/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9644 - mae: 0.7244 - val_loss: 1.0164 - val_mae: 0.7761
# Epoch 53/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9670 - mae: 0.7242 - val_loss: 1.0221 - val_mae: 0.7696
# Epoch 54/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9526 - mae: 0.7247 - val_loss: 1.0198 - val_mae: 0.7781
# Epoch 55/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9574 - mae: 0.7226 - val_loss: 1.0262 - val_mae: 0.7688
# Epoch 56/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9587 - mae: 0.7251 - val_loss: 1.0235 - val_mae: 0.7720
# Epoch 57/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9619 - mae: 0.7244 - val_loss: 1.0170 - val_mae: 0.7706
# Epoch 58/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9576 - mae: 0.7211 - val_loss: 1.0138 - val_mae: 0.7718
# Epoch 59/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9536 - mae: 0.7238 - val_loss: 1.0169 - val_mae: 0.7701
# Epoch 60/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9530 - mae: 0.7214 - val_loss: 1.0188 - val_mae: 0.7714
# Epoch 61/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9613 - mae: 0.7258 - val_loss: 1.0156 - val_mae: 0.7683
# Epoch 62/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9531 - mae: 0.7234 - val_loss: 1.0159 - val_mae: 0.7703
# Epoch 63/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.9626 - mae: 0.7260 - val_loss: 1.0163 - val_mae: 0.7676
# Epoch 64/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9496 - mae: 0.7192 - val_loss: 1.0156 - val_mae: 0.7684
# Epoch 65/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.9495 - mae: 0.7221 - val_loss: 1.0172 - val_mae: 0.7683
# Epoch 66/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9530 - mae: 0.7219 - val_loss: 1.0153 - val_mae: 0.7659
# Epoch 67/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.9555 - mae: 0.7202 - val_loss: 1.0165 - val_mae: 0.7680
# Epoch 68/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.9480 - mae: 0.7217 - val_loss: 1.0160 - val_mae: 0.7674
# Epoch 69/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.9488 - mae: 0.7228 - val_loss: 1.0118 - val_mae: 0.7745
# Epoch 70/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9448 - mae: 0.7218 - val_loss: 1.0145 - val_mae: 0.7676
# Epoch 71/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9463 - mae: 0.7196 - val_loss: 1.0123 - val_mae: 0.7689
# Epoch 72/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9439 - mae: 0.7224 - val_loss: 1.0147 - val_mae: 0.7662
# Epoch 73/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9412 - mae: 0.7188 - val_loss: 1.0135 - val_mae: 0.7664
# Epoch 74/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9478 - mae: 0.7226 - val_loss: 1.0127 - val_mae: 0.7691
# Epoch 75/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.9443 - mae: 0.7213 - val_loss: 1.0092 - val_mae: 0.7717
# Epoch 76/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.9399 - mae: 0.7206 - val_loss: 1.0100 - val_mae: 0.7663
# Epoch 77/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9413 - mae: 0.7180 - val_loss: 1.0073 - val_mae: 0.7688
# Epoch 78/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9446 - mae: 0.7201 - val_loss: 1.0083 - val_mae: 0.7691
# Epoch 79/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9439 - mae: 0.7204 - val_loss: 1.0110 - val_mae: 0.7640
# Epoch 80/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9462 - mae: 0.7194 - val_loss: 1.0106 - val_mae: 0.7666
# Epoch 81/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9431 - mae: 0.7196 - val_loss: 1.0091 - val_mae: 0.7702
# Epoch 82/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9422 - mae: 0.7193 - val_loss: 1.0107 - val_mae: 0.7673
# Epoch 83/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9313 - mae: 0.7174 - val_loss: 1.0120 - val_mae: 0.7670
# Epoch 84/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9451 - mae: 0.7181 - val_loss: 1.0141 - val_mae: 0.7652
# Epoch 85/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9389 - mae: 0.7177 - val_loss: 1.0140 - val_mae: 0.7670
# Epoch 86/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9407 - mae: 0.7171 - val_loss: 1.0133 - val_mae: 0.7673
# Epoch 87/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9388 - mae: 0.7179 - val_loss: 1.0131 - val_mae: 0.7678
# Epoch 88/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9286 - mae: 0.7132 - val_loss: 1.0124 - val_mae: 0.7687
# Epoch 89/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9386 - mae: 0.7161 - val_loss: 1.0162 - val_mae: 0.7658
# Epoch 90/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9364 - mae: 0.7185 - val_loss: 1.0163 - val_mae: 0.7699
# Epoch 91/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9324 - mae: 0.7160 - val_loss: 1.0183 - val_mae: 0.7637
# Epoch 92/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9401 - mae: 0.7170 - val_loss: 1.0156 - val_mae: 0.7628
# Epoch 93/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9373 - mae: 0.7202 - val_loss: 1.0106 - val_mae: 0.7747
# Epoch 94/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9256 - mae: 0.7124 - val_loss: 1.0153 - val_mae: 0.7641
# Epoch 95/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9402 - mae: 0.7205 - val_loss: 1.0150 - val_mae: 0.7667
# Epoch 96/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9296 - mae: 0.7165 - val_loss: 1.0145 - val_mae: 0.7681
# Epoch 97/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9242 - mae: 0.7118 - val_loss: 1.0129 - val_mae: 0.7715
# Epoch 98/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.9221 - mae: 0.7100 - val_loss: 1.0124 - val_mae: 0.7676
# Epoch 99/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9309 - mae: 0.7153 - val_loss: 1.0136 - val_mae: 0.7659
# Epoch 100/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.9254 - mae: 0.7146 - val_loss: 1.0125 - val_mae: 0.7664

# %%
# Plot
plt.plot(r.history['loss'], label='Train Loss')
plt.plot(r.history['val_loss'], label='Test Loss')
plt.legend();

# %%
# Make Prediction
# Note that we do not flatten() the prediction
Ptrain = model.predict(Xtrain_m)
Ptest = model.predict(Xtest_m)
# Out:
# 29/29 [==============================] - 1s 3ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
# Shape
Ptrain.shape, Ptest.shape
# Out:
# ((909, 10), (1, 10))

# %%
# Index our prediction
Ptrain = Ptrain[:, 0]
Ptest = Ptest[0]

# %%
# Unscale
Ptest = scaler.inverse_transform(Ptest.reshape(-1,1)).flatten()

# %%
# Save Multi-Step Forecast to DataFrame
df.loc[test_idx, 'Multi_OutPut'] = last_train + np.cumsum(Ptest)

# %%
# Plot all Forecasts
px.line(df, x=df.index, y=['Log_Close', '1_Step_pred_Test', 'Multi_Step', 'Multi_OutPut'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0d125253-75d9-417c-9bbe-9623a6c05f1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d125253-75d9-417c-9bbe-9623a6c05f1e")) {                    Plotly.newPlot(                        "0d125253-75d9-417c-9bbe-9623a6c05f1e",                        [{"hovertemplate":"variable=Log_Close\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Log_Close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Log_Close","showlegend":true,"x":["2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:00:00","2020-01-17T00:00:00","2020-01-21T00:00:00","2020-01-22T00:00:00","2020-01-23T00:00:00","2020-01-24T00:00:00","2020-01-27T00:00:00","2020-01-28T00:00:00","2020-01-29T00:00:00","2020-01-30T00:00:00","2020-01-31T00:00:00","2020-02-03T00:00:00","2020-02-04T00:00:00","2020-02-05T00:00:00","2020-02-06T00:00:00","2020-02-07T00:00:00","2020-02-10T00:00:00","2020-02-11T00:00:00","2020-02-12T00:00:00","2020-02-13T00:00:00","2020-02-14T00:00:00","2020-02-18T00:00:00","2020-02-19T00:00:00","2020-02-20T00:00:00","2020-02-21T00:00:00","2020-02-24T00:00:00","2020-02-25T00:00:00","2020-02-26T00:00:00","2020-02-27T00:00:00","2020-02-28T00:00:00","2020-03-02T00:00:00","2020-03-03T00:00:00","2020-03-04T00:00:00","2020-03-05T00:00:00","2020-03-06T00:00:00","2020-03-09T00:00:00","2020-03-10T00:00:00","2020-03-11T00:00:00","2020-03-12T00:00:00","2020-03-13T00:00:00","2020-03-16T00:00:00","2020-03-17T00:00:00","2020-03-18T00:00:00","2020-03-19T00:00:00","2020-03-20T00:00:00","2020-03-23T00:00:00","2020-03-24T00:00:00","2020-03-25T00:00:00","2020-03-26T00:00:00","2020-03-27T00:00:00","2020-03-30T00:00:00","2020-03-31T00:00:00","2020-04-01T00:00:00","2020-04-02T00:00:00","2020-04-03T00:00:00","2020-04-06T00:00:00","2020-04-07T00:00:00","2020-04-08T00:00:00","2020-04-09T00:00:00","2020-04-13T00:00:00","2020-04-14T00:00:00","2020-04-15T00:00:00","2020-04-16T00:00:00","2020-04-17T00:00:00","2020-04-20T00:00:00","2020-04-21T00:00:00","2020-04-22T00:00:00","2020-04-23T00:00:00","2020-04-24T00:00:00","2020-04-27T00:00:00","2020-04-28T00:00:00","2020-04-29T00:00:00","2020-04-30T00:00:00","2020-05-01T00:00:00","2020-05-04T00:00:00","2020-05-05T00:00:00","2020-05-06T00:00:00","2020-05-07T00:00:00","2020-05-08T00:00:00","2020-05-11T00:00:00","2020-05-12T00:00:00","2020-05-13T00:00:00","2020-05-14T00:00:00","2020-05-15T00:00:00","2020-05-18T00:00:00","2020-05-19T00:00:00","2020-05-20T00:00:00","2020-05-21T00:00:00","2020-05-22T00:00:00","2020-05-26T00:00:00","2020-05-27T00:00:00","2020-05-28T00:00:00","2020-05-29T00:00:00","2020-06-01T00:00:00","2020-06-02T00:00:00","2020-06-03T00:00:00","2020-06-04T00:00:00","2020-06-05T00:00:00","2020-06-08T00:00:00","2020-06-09T00:00:00","2020-06-10T00:00:00","2020-06-11T00:00:00","2020-06-12T00:00:00","2020-06-15T00:00:00","2020-06-16T00:00:00","2020-06-17T00:00:00","2020-06-18T00:00:00","2020-06-19T00:00:00","2020-06-22T00:00:00","2020-06-23T00:00:00","2020-06-24T00:00:00","2020-06-25T00:00:00","2020-06-26T00:00:00","2020-06-29T00:00:00","2020-06-30T00:00:00","2020-07-01T00:00:00","2020-07-02T00:00:00","2020-07-06T00:00:00","2020-07-07T00:00:00","2020-07-08T00:00:00","2020-07-09T00:00:00","2020-07-10T00:00:00","2020-07-13T00:00:00","2020-07-14T00:00:00","2020-07-15T00:00:00","2020-07-16T00:00:00","2020-07-17T00:00:00","2020-07-20T00:00:00","2020-07-21T00:00:00","2020-07-22T00:00:00","2020-07-23T00:00:00","2020-07-24T00:00:00","2020-07-27T00:00:00","2020-07-28 ...

# %%
# MAPE
test_log_Close = df.iloc[-Ntest:]['Log_Close']
mape_1 = mean_absolute_percentage_error(test_log_Close, df.loc[test_idx, '1_Step_pred_Test'])
print('1Step MAPE: ', mape_1)
mape_2 = mean_absolute_percentage_error(test_log_Close, df.loc[test_idx, 'Multi_Step'])
print('Multi-Step MAPE: ', mape_2)
mape_3 = mean_absolute_percentage_error(test_log_Close, df.loc[test_idx, 'Multi_OutPut'])
print('Multi-OutPut MAPE: ', mape_3)
# Out:
# 1Step MAPE:  0.0006979963581228187
# Multi-Step MAPE:  0.0011516512985628965
# Multi-OutPut MAPE:  0.0011552988882276081

# %%
# R2 Score
test_log_Close = df.iloc[-Ntest:]['Log_Close']
R2_1 = r2_score(test_log_Close, df.loc[test_idx, '1_Step_pred_Test'])
print('1Step R2: ', R2_1)
R2_2 = r2_score(test_log_Close, df.loc[test_idx, 'Multi_Step'])
print('Multi-Step R2: ', R2_2)
R2_3 = r2_score(test_log_Close, df.loc[test_idx, 'Multi_OutPut'])
print('Multi-OutPut R2: ', R2_3)
# Out:
# 1Step R2:  0.3216840121929637
# Multi-Step R2:  -0.8067551501801018
# Multi-OutPut R2:  -0.8035572226305543
